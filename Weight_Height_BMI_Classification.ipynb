# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/AI_ML_Internship Aug batch/knn - Sheet1.csv")
df
# Out:
#     Weight(x2)  Height(y2)        Class
# 0           51         167  Underweight
# 1           66         177       Normal
# 2           75         169   Overweight
# 3           69         176       Normal
# 4           50         173  Underweight
# 5           82         170   Overweight
# 6           65         172       Normal
# 7           58         180  Underweight
# 8           68         162   Overweight
# 9           63         165       Normal
# 10          52         174  Underweight
# 11          58         169       Normal
# 12          78         162   Overweight
# 13          65         168       Normal
# 14          62         183  Underweight
# 15          72         180       Normal
# 16          80         180   Overweight
# 17          60         178  Underweight
# 18          57         173       Normal
# 19          73         164   Overweight
# 20          53         170  Underweight
# 21          74         182       Normal
# ...

# %%
x = df.iloc[:,0:2].values
y= df.iloc[:,2].values
y
# Out:
# array(['Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight',
#        'Overweight', 'Normal', 'Underweight', 'Overweight', 'Normal',
#        'Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight',
#        'Normal', 'Overweight', 'Underweight', 'Normal', 'Overweight',
#        'Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight'],
#       dtype=object)

# %%
k=5
pred=[60,175]

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=k, metric='euclidean')
model.fit(x,y)
y_pred=model.predict([pred])
y_pred
# Out:
# array(['Normal'], dtype=object)

# %%
# df

# %%
df1= df[df['Class']=='Normal']
df2= df[df['Class']=='Underweight']
df3= df[df['Class']=='Overweight']
plt.figure(figsize=(20,4))
plt.scatter(df1['Weight(x2)'],df1['Height(y2)'],label="Normal")
plt.scatter(df2['Weight(x2)'],df2['Height(y2)'],label="Underweight")
plt.scatter(df3['Weight(x2)'],df3['Height(y2)'],label="Overweight")
plt.scatter(pred[0],pred[1],c='k',s=100)
plt.xlabel('Weight in kgs')
plt.ylabel('Height in cm')
plt.title('weight analysis')
plt.legend(loc='lower right')
plt.xticks(np.arange(45, 85, 4))
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import numpy as np

k = range(1,20)
total_acc = []

for i in k:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x,y)
    acc = knn.score(x,y)
    total_acc.append(acc)
plt.xlabel("value of K")
plt.ylabel("Acciracy")
plt.title("Select best value of k")
plt.plot(k,total_acc)
plt.xticks(np.arange(0, 21, 1))
plt.yticks(np.arange(0, 1.1, 0.1))
# Out:
# ([<matplotlib.axis.YTick at 0x7f718d779c50>,
# ...
#  <a list of 11 Text major ticklabel objects>)
